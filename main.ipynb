# %%
#Importing library

# %matplotlib inline
import numpy as np
import os
import cv2

import matplotlib
import matplotlib.pyplot as plt
import math

import keras
from keras.layers import (Input, Activation, Conv3D, Dense, Dropout, Flatten, 
                          MaxPooling3D, BatchNormalization, AveragePooling3D, 
                          Reshape, Lambda, GlobalAveragePooling3D, Concatenate,
                          ReLU, Add)

from keras.losses import categorical_crossentropy
from keras.models import Sequential, Model, load_model
from keras.optimizers import gradient_descent_v2
from keras.utils import np_utils
from keras.utils.vis_utils import plot_model
from keras.utils import layer_utils
from keras.utils.layer_utils import get_source_inputs
from keras.utils.data_utils import get_file

from sklearn.model_selection import train_test_split

from keras.callbacks import ModelCheckpoint

import tensorflow as tf
from keras.backend import set_session

from keras.callbacks import CSVLogger

# %%
def plot_history(history, result_dir):
    '''
    Plots the accuracy and loss graphs of train and val and saves them.
    '''

    plt.plot(history.history['accuracy'], marker='.')
    plt.plot(history.history['val_accuracy'], marker='.')
    plt.title('model accuracy')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.grid()
    plt.legend(['accuracy', 'val_accuracy'], loc='lower right')
    plt.savefig(os.path.join(result_dir, 'model_accuracy.png'))
    plt.show()

    plt.plot(history.history['loss'], marker='.')
    plt.plot(history.history['val_loss'], marker='.')
    plt.title('model loss')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.grid()
    plt.legend(['loss', 'val_loss'], loc='upper right')
    plt.savefig(os.path.join(result_dir, 'model_loss.png'))
    plt.show();

# %%
class Videoto3D:
    def __init__(self, width, height, depth):
        self.width = width
        self.height = height
        self.depth = depth

    def video3d(self, folder_path):
        frames = []
        
        # Get the list of video files inside the folder
        video_files = os.listdir(folder_path)
        video_files = [f for f in video_files if f.endswith('.mp4')]  # Adjust the extension if necessary
        video_files.sort()

        # Iterate over each video file
        for video in video_files:
            video_path = os.path.join(folder_path, video)
            cap = cv2.VideoCapture(video_path)
            total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
            frame_interval = max(1, total_frames // self.depth)

            count = 0
            while len(frames) < self.depth:
                ret, frame = cap.read()
                if not ret:
                    break
                if count % frame_interval == 0:
                    frame = cv2.resize(frame, (self.height, self.width))
                    frames.append(frame)
                count += 1

            cap.release()

            if len(frames) >= self.depth:
                break  # Stop once we've collected enough frames

        # If we couldn't extract enough frames, pad the list with empty frames
        while len(frames) < self.depth:
            frames.append(np.zeros((self.height, self.width, 3)))

        return np.array(frames) / 255.0

# %%
def preprocess(video_dir, result_dir, nb_classes = 101, img_size = 224, frames = 25):
    '''
    Preprocess the videos into X and Y and saves in npz format and 
    computes input shape
    '''

    img_rows, img_cols  = img_size, img_size

    channel = 3

    files = os.listdir(video_dir)
    files.sort()

    if '.ipynb_checkpoints' in files:
        files.remove('.ipynb_checkpoints')

    X = []
    labels = []
    labellist = []

    # Obtain labels and X
    for filename in files:
        if filename == "Labels":
            continue
        name = os.path.join(video_dir, filename)
        
        for v_files in os.listdir(name):
            
            v_file_path = os.path.join(name, v_files)
            label = filename
            if label not in labellist:
                if len(labellist) >= nb_classes:
                    continue
                labellist.append(label)
            labels.append(label)
            X.append(v_file_path)

    if not os.path.isdir(result_dir):
        os.makedirs(result_dir)
    with open(os.path.join(result_dir, 'classes.txt'), 'w') as fp:
        for i in range(len(labellist)):
            fp.write('{} {}\n'.format(i, labellist[i]))

    for num, label in enumerate(labellist):
        for i in range(len(labels)):
            if label == labels[i]:
                labels[i] = num
                
    Y = np_utils.to_categorical(labels, nb_classes)
    
    print('X_shape:{}\tY_shape:{}'.format(len(X), Y.shape))

    input_shape = (frames, img_rows, img_cols, channel)

    return X, Y, input_shape

# %%
from slowfast import *

def resnet50(inputs, **kwargs):
    model = SlowFast_body(inputs, [3, 4, 6, 3], bottleneck, **kwargs)
    return model

# %%
class batchGenerator(keras.utils.Sequence):

    def __init__(self, x_set, y_set, batch_size, vid3d):
        self.x, self.y = x_set, y_set
        self.batch_size = batch_size
        self.vid3d = vid3d

    def __len__(self):
        return math.ceil(len(self.x) / self.batch_size)

    def __getitem__(self, idx):
        batch_x = []

        for video in self.x[idx * self.batch_size:(idx + 1) * self.batch_size]:
            batch_x.append(self.vid3d.video3d(video))

        batch_x = np.array(batch_x)
        batch_x = batch_x.astype('float32')
        batch_y = self.y[idx * self.batch_size:(idx + 1) * self.batch_size]

        return batch_x, batch_y

# %%
def main(video_dir, result_dir, nb_classes = 101, batch_size = 32, epochs = 100, img_size = 224, frames = 25):

    X, Y, input_shape = preprocess(video_dir, result_dir, nb_classes, img_size, 
                                   frames)

    print("Input Shape = ", input_shape)

    vid3d = Videoto3D(img_size, img_size, frames)

    ## For i3D Inception model ##
#     i3dmodel = Inception_Inflated3d(include_top=False,
#                 weights='rgb_imagenet_and_kinetics',
#                 input_tensor=None,
#                 input_shape=input_shape,
#                 dropout_prob=0.5,
#                 endpoint_logit=False)
    
#     model = I3DModel(i3dmodel, nb_classes)
    
    ## For Slowfast model ##
    x = Input(shape = input_shape)
    model = resnet50(x, num_classes=nb_classes)

    model.compile(loss='categorical_crossentropy',
                  optimizer=gradient_descent_v2.SGD(learning_rate=0.01, momentum=0.9), 
                  metrics=['accuracy'])
    
#     model = load_model(os.path.join(result_dir, "slowfast-77-0.73.hd5"))
    
    model.summary()

    X_train, X_test, Y_train, Y_test = train_test_split(
        X, Y, test_size=0.15, shuffle = True)
    
    X_train, X_val, Y_train, Y_val = train_test_split(
        X_train, Y_train, test_size=0.15, shuffle = True)

    print("X_train.shape = ", len(X_train))
    print("X_val.shape = ", len(X_val))
    print("X_test.shape = ", len(X_test))

    # MODEL CHECK POINTS #

    csv_logger = CSVLogger(os.path.join(result_dir, "slowfast_model_history_log.csv"), append=True)

    filepath = os.path.join(result_dir, "slowfast-{epoch:02d}-{val_accuracy:.2f}.hdf5")
    checkpoint = keras.callbacks.ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, mode='max')
    callbacks_list = [checkpoint, csv_logger]

    history = model.fit(batchGenerator(X_train, Y_train, batch_size, vid3d), steps_per_epoch = math.ceil(len(X_train) / batch_size), 
                                  validation_data = batchGenerator(X_val, Y_val, batch_size, vid3d), validation_steps = math.ceil(len(X_val) / batch_size), 
                                  epochs = epochs, verbose = 1, callbacks=callbacks_list, initial_epoch = 0)

    model_json = model.to_json()
    
    if not os.path.isdir(result_dir):
        os.makedirs(result_dir)
    with open(os.path.join(result_dir, 'slowfast.json'), 'w') as json_file:
        json_file.write(model_json)
    
    model.save_weights(os.path.join(result_dir, 'slowfast_finalweights.hdf5'))

    model.save(os.path.join(result_dir, "slowfast_finalmodel.hdf5"))

    loss, acc = model.evaluate(batchGenerator(X_test, Y_test, batch_size, vid3d),
                               steps = math.ceil(len(X_test) / batch_size), verbose = 1)
    
    plot_history(history, result_dir)

    print('Test loss:', loss)
    print('Test accuracy:', acc)

    return history, model

# %%
## TRAIN MODEL ##

history, model = main(video_dir = 'DCSASS Dataset/', result_dir = 'output/', nb_classes = 14, batch_size = 2, epochs = 5, img_size = 224, frames = 25)
# Out:
# X_shape:520	Y_shape:(520, 14)
# Input Shape =  (25, 224, 224, 3)
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 25, 224, 22  0           []
#                                 4, 3)]
#
#  data_fast (Lambda)             (None, 13, 224, 224  0           ['input_2[0][0]']
#                                 , 3)
#
#  data_slow (Lambda)             (None, 2, 224, 224,  0           ['input_2[0][0]']
#                                  3)
#
#  sequential_74 (Sequential)     (None, 13, 112, 112  5912        ['data_fast[0][0]']
#                                 , 8)
#
#  sequential_111 (Sequential)    (None, 2, 112, 112,  9664        ['data_slow[0][0]']
#                                  64)
#
#  max_pooling3d_2 (MaxPooling3D)  (None, 13, 56, 56,   0          ['sequential_74[0][0]']
#                                 8)
#
#  max_pooling3d_3 (MaxPooling3D)  (None, 2, 56, 56, 6  0          ['sequential_111[0][0]']
#                                 4)
#
#  conv3d_111 (Conv3D)            (None, 2, 56, 56, 1  640         ['max_pooling3d_2[0][0]']
#                                 6)
#
#  concatenate_5 (Concatenate)    (None, 2, 56, 56, 8  0           ['max_pooling3d_3[0][0]',
#                                 0)                                'conv3d_111[0][0]']
#
#  sequential_76 (Sequential)     (None, 13, 56, 56,   224         ['max_pooling3d_2[0][0]']
#                                 8)
#
#  sequential_113 (Sequential)    (None, 2, 56, 56, 6  5376        ['concatenate_5[0][0]']
#                                 4)
#
#  sequential_77 (Sequential)     (None, 13, 56, 56,   608         ['sequential_76[0][0]']
#                                 8)
#
#  sequential_114 (Sequential)    (None, 2, 56, 56, 6  37120       ['sequential_113[0][0]']
#                                 4)
#
#  conv3d_115 (Conv3D)            (None, 13, 56, 56,   256         ['sequential_77[0][0]']
#                                 32)
#
#  conv3d_171 (Conv3D)            (None, 2, 56, 56, 2  16384       ['sequential_114[0][0]']
#                                 56)
#
#  batch_normalization_110 (Batch  (None, 13, 56, 56,   128        ['conv3d_115[0][0]']
#  Normalization)                 32)
#
#  sequential_75 (Sequential)     (None, 13, 56, 56,   384         ['max_pooling3d_2[0][0]']
#                                 32)
#
#  batch_normalization_163 (Batch  (None, 2, 56, 56, 2  1024       ['conv3d_171[0][0]']
#  Normalization)                 56)
#
#  sequential_112 (Sequential)    (None, 2, 56, 56, 2  21504       ['concatenate_5[0][0]']
#                                 56)
#
#  add_32 (Add)                   (None, 13, 56, 56,   0           ['batch_normalization_110[0][0]',
#                                 32)                               'sequential_75[0][0]']
#
#  add_48 (Add)                   (None, 2, 56, 56, 2  0           ['batch_normalization_163[0][0]',
#                                 56)                               'sequential_112[0][0]']
#
#  re_lu_101 (ReLU)               (None, 13, 56, 56,   0           ['add_32[0][0]']
#                                 32)
#
#  re_lu_150 (ReLU)               (None, 2, 56, 56, 2  0           ['add_48[0][0]']
#                                 56)
#
#  sequential_78 (Sequential)     (None, 13, 56, 56,   800         ['re_lu_101[0][0]']
#                                 8)
#
#  sequential_115 (Sequential)    (None, 2, 56, 56, 6  16640       ['re_lu_150[0][0]']
#                                 4)
#
#  sequential_79 (Sequential)     (None, 13, 56, 56,   608         ['sequential_78[0][0]']
#                                 8)
#
#  sequential_116 (Sequential)    (None, 2, 56, 56, 6  37120       ['sequential_115[0][0]']
#                                 4)
#
#  conv3d_118 (Conv3D)            (None, 13, 56, 56,   256         ['sequential_79[0][0]']
#                                 32)
#
#  conv3d_174 (Conv3D)            (None, 2, 56, 56, 2  16384       ['sequential_116[0][0]']
#                                 56)
#
#  batch_normalization_113 (Batch  (None, 13, 56, 56,   128        ['conv3d_118[0][0]']
#  Normalization)                 32)
#
#  batch_normalization_166 (Batch  (None, 2, 56, 56, 2  1024       ['conv3d_174[0][0]']
#  Normalization)                 56)
#
#  add_33 (Add)                   (None, 13, 56, 56,   0           ['batch_normalization_113[0][0]',
#                                 32)                               're_lu_101[0][0]']
#
#  add_49 (Add)                   (None, 2, 56, 56, 2  0           ['batch_normalization_166[0][0]',
#                                 56)                               're_lu_150[0][0]']
#
#  re_lu_104 (ReLU)               (None, 13, 56, 56,   0           ['add_33[0][0]']
#                                 32)
#
#  re_lu_153 (ReLU)               (None, 2, 56, 56, 2  0           ['add_49[0][0]']
#                                 56)
#
#  sequential_80 (Sequential)     (None, 13, 56, 56,   800         ['re_lu_104[0][0]']
#                                 8)
#
#  sequential_117 (Sequential)    (None, 2, 56, 56, 6  16640       ['re_lu_153[0][0]']
#                                 4)
#
#  sequential_81 (Sequential)     (None, 13, 56, 56,   608         ['sequential_80[0][0]']
#                                 8)
#
#  sequential_118 (Sequential)    (None, 2, 56, 56, 6  37120       ['sequential_117[0][0]']
#                                 4)
#
#  conv3d_121 (Conv3D)            (None, 13, 56, 56,   256         ['sequential_81[0][0]']
#                                 32)
#
#  conv3d_177 (Conv3D)            (None, 2, 56, 56, 2  16384       ['sequential_118[0][0]']
#                                 56)
#
#  batch_normalization_116 (Batch  (None, 13, 56, 56,   128        ['conv3d_121[0][0]']
#  Normalization)                 32)
#
#  batch_normalization_169 (Batch  (None, 2, 56, 56, 2  1024       ['conv3d_177[0][0]']
#  Normalization)                 56)
#
#  add_34 (Add)                   (None, 13, 56, 56,   0           ['batch_normalization_116[0][0]',
#                                 32)                               're_lu_104[0][0]']
#
#  add_50 (Add)                   (None, 2, 56, 56, 2  0           ['batch_normalization_169[0][0]',
#                                 56)                               're_lu_153[0][0]']
#
#  re_lu_107 (ReLU)               (None, 13, 56, 56,   0           ['add_34[0][0]']
#                                 32)
#
#  re_lu_156 (ReLU)               (None, 2, 56, 56, 2  0           ['add_50[0][0]']
#                                 56)
#
#  conv3d_122 (Conv3D)            (None, 2, 56, 56, 6  10240       ['re_lu_107[0][0]']
#                                 4)
#
#  concatenate_6 (Concatenate)    (None, 2, 56, 56, 3  0           ['re_lu_156[0][0]',
#                                 20)                               'conv3d_122[0][0]']
#
#  sequential_83 (Sequential)     (None, 13, 56, 56,   1600        ['re_lu_107[0][0]']
#                                 16)
#
#  sequential_120 (Sequential)    (None, 2, 56, 56, 1  41472       ['concatenate_6[0][0]']
#                                 28)
#
#  sequential_84 (Sequential)     (None, 13, 28, 28,   2368        ['sequential_83[0][0]']
#                                 16)
#
#  sequential_121 (Sequential)    (None, 2, 28, 28, 1  147968      ['sequential_120[0][0]']
#                                 28)
#
#  conv3d_126 (Conv3D)            (None, 13, 28, 28,   1024        ['sequential_84[0][0]']
#                                 64)
#
#  conv3d_181 (Conv3D)            (None, 2, 28, 28, 5  65536       ['sequential_121[0][0]']
#                                 12)
#
#  batch_normalization_120 (Batch  (None, 13, 28, 28,   256        ['conv3d_126[0][0]']
#  Normalization)                 64)
#
#  sequential_82 (Sequential)     (None, 13, 28, 28,   2304        ['re_lu_107[0][0]']
#                                 64)
#
#  batch_normalization_173 (Batch  (None, 2, 28, 28, 5  2048       ['conv3d_181[0][0]']
#  Normalization)                 12)
#
#  sequential_119 (Sequential)    (None, 2, 28, 28, 5  165888      ['concatenate_6[0][0]']
#                                 12)
#
#  add_35 (Add)                   (None, 13, 28, 28,   0           ['batch_normalization_120[0][0]',
#                                 64)                               'sequential_82[0][0]']
#
#  add_51 (Add)                   (None, 2, 28, 28, 5  0           ['batch_normalization_173[0][0]',
#                                 12)                               'sequential_119[0][0]']
#
#  re_lu_110 (ReLU)               (None, 13, 28, 28,   0           ['add_35[0][0]']
#                                 64)
#
#  re_lu_159 (ReLU)               (None, 2, 28, 28, 5  0           ['add_51[0][0]']
#                                 12)
#
#  sequential_85 (Sequential)     (None, 13, 28, 28,   3136        ['re_lu_110[0][0]']
#                                 16)
#
#  sequential_122 (Sequential)    (None, 2, 28, 28, 1  66048       ['re_lu_159[0][0]']
#                                 28)
#
#  sequential_86 (Sequential)     (None, 13, 28, 28,   2368        ['sequential_85[0][0]']
#                                 16)
#
#  sequential_123 (Sequential)    (None, 2, 28, 28, 1  147968      ['sequential_122[0][0]']
#                                 28)
#
#  conv3d_129 (Conv3D)            (None, 13, 28, 28,   1024        ['sequential_86[0][0]']
#                                 64)
#
#  conv3d_184 (Conv3D)            (None, 2, 28, 28, 5  65536       ['sequential_123[0][0]']
#                                 12)
#
#  batch_normalization_123 (Batch  (None, 13, 28, 28,   256        ['conv3d_129[0][0]']
#  Normalization)                 64)
#
#  batch_normalization_176 (Batch  (None, 2, 28, 28, 5  2048       ['conv3d_184[0][0]']
#  Normalization)                 12)
#
#  add_36 (Add)                   (None, 13, 28, 28,   0           ['batch_normalization_123[0][0]',
#                                 64)                               're_lu_110[0][0]']
#
#  add_52 (Add)                   (None, 2, 28, 28, 5  0           ['batch_normalization_176[0][0]',
#                                 12)                               're_lu_159[0][0]']
#
#  re_lu_113 (ReLU)               (None, 13, 28, 28,   0           ['add_36[0][0]']
#                                 64)
#
#  re_lu_162 (ReLU)               (None, 2, 28, 28, 5  0           ['add_52[0][0]']
#                                 12)
#
#  sequential_87 (Sequential)     (None, 13, 28, 28,   3136        ['re_lu_113[0][0]']
#                                 16)
#
#  sequential_124 (Sequential)    (None, 2, 28, 28, 1  66048       ['re_lu_162[0][0]']
#                                 28)
#
#  sequential_88 (Sequential)     (None, 13, 28, 28,   2368        ['sequential_87[0][0]']
#                                 16)
#
#  sequential_125 (Sequential)    (None, 2, 28, 28, 1  147968      ['sequential_124[0][0]']
#                                 28)
#
#  conv3d_132 (Conv3D)            (None, 13, 28, 28,   1024        ['sequential_88[0][0]']
#                                 64)
#
#  conv3d_187 (Conv3D)            (None, 2, 28, 28, 5  65536       ['sequential_125[0][0]']
#                                 12)
#
#  batch_normalization_126 (Batch  (None, 13, 28, 28,   256        ['conv3d_132[0][0]']
#  Normalization)                 64)
#
#  batch_normalization_179 (Batch  (None, 2, 28, 28, 5  2048       ['conv3d_187[0][0]']
#  Normalization)                 12)
#
#  add_37 (Add)                   (None, 13, 28, 28,   0           ['batch_normalization_126[0][0]',
#                                 64)                               're_lu_113[0][0]']
#
#  add_53 (Add)                   (None, 2, 28, 28, 5  0           ['batch_normalization_179[0][0]',
#                                 12)                               're_lu_162[0][0]']
#
#  re_lu_116 (ReLU)               (None, 13, 28, 28,   0           ['add_37[0][0]']
#                                 64)
#
#  re_lu_165 (ReLU)               (None, 2, 28, 28, 5  0           ['add_53[0][0]']
#                                 12)
#
#  sequential_89 (Sequential)     (None, 13, 28, 28,   3136        ['re_lu_116[0][0]']
#                                 16)
#
#  sequential_126 (Sequential)    (None, 2, 28, 28, 1  66048       ['re_lu_165[0][0]']
#                                 28)
#
#  sequential_90 (Sequential)     (None, 13, 28, 28,   2368        ['sequential_89[0][0]']
#                                 16)
#
#  sequential_127 (Sequential)    (None, 2, 28, 28, 1  147968      ['sequential_126[0][0]']
#                                 28)
#
#  conv3d_135 (Conv3D)            (None, 13, 28, 28,   1024        ['sequential_90[0][0]']
#                                 64)
#
#  conv3d_190 (Conv3D)            (None, 2, 28, 28, 5  65536       ['sequential_127[0][0]']
#                                 12)
#
#  batch_normalization_129 (Batch  (None, 13, 28, 28,   256        ['conv3d_135[0][0]']
#  Normalization)                 64)
#
#  batch_normalization_182 (Batch  (None, 2, 28, 28, 5  2048       ['conv3d_190[0][0]']
#  Normalization)                 12)
#
#  add_38 (Add)                   (None, 13, 28, 28,   0           ['batch_normalization_129[0][0]',
#                                 64)                               're_lu_116[0][0]']
#
#  add_54 (Add)                   (None, 2, 28, 28, 5  0           ['batch_normalization_182[0][0]',
#                                 12)                               're_lu_165[0][0]']
#
#  re_lu_119 (ReLU)               (None, 13, 28, 28,   0           ['add_38[0][0]']
#                                 64)
#
#  re_lu_168 (ReLU)               (None, 2, 28, 28, 5  0           ['add_54[0][0]']
#                                 12)
#
#  conv3d_136 (Conv3D)            (None, 2, 28, 28, 1  40960       ['re_lu_119[0][0]']
#                                 28)
#
#  concatenate_7 (Concatenate)    (None, 2, 28, 28, 6  0           ['re_lu_168[0][0]',
#                                 40)                               'conv3d_136[0][0]']
#
#  sequential_92 (Sequential)     (None, 13, 28, 28,   6272        ['re_lu_119[0][0]']
#                                 32)
#
#  sequential_129 (Sequential)    (None, 2, 28, 28, 2  164864      ['concatenate_7[0][0]']
#                                 56)
#
#  sequential_93 (Sequential)     (None, 13, 14, 14,   9344        ['sequential_92[0][0]']
#                                 32)
#
#  sequential_130 (Sequential)    (None, 2, 14, 14, 2  590848      ['sequential_129[0][0]']
#                                 56)
#
#  conv3d_140 (Conv3D)            (None, 13, 14, 14,   4096        ['sequential_93[0][0]']
#                                 128)
#
#  conv3d_194 (Conv3D)            (None, 2, 14, 14, 1  262144      ['sequential_130[0][0]']
#                                 024)
#
#  batch_normalization_133 (Batch  (None, 13, 14, 14,   512        ['conv3d_140[0][0]']
#  Normalization)                 128)
#
#  sequential_91 (Sequential)     (None, 13, 14, 14,   8704        ['re_lu_119[0][0]']
#                                 128)
#
#  batch_normalization_186 (Batch  (None, 2, 14, 14, 1  4096       ['conv3d_194[0][0]']
#  Normalization)                 024)
#
#  sequential_128 (Sequential)    (None, 2, 14, 14, 1  659456      ['concatenate_7[0][0]']
#                                 024)
#
#  add_39 (Add)                   (None, 13, 14, 14,   0           ['batch_normalization_133[0][0]',
#                                 128)                              'sequential_91[0][0]']
#
#  add_55 (Add)                   (None, 2, 14, 14, 1  0           ['batch_normalization_186[0][0]',
#                                 024)                              'sequential_128[0][0]']
#
#  re_lu_122 (ReLU)               (None, 13, 14, 14,   0           ['add_39[0][0]']
#                                 128)
#
#  re_lu_171 (ReLU)               (None, 2, 14, 14, 1  0           ['add_55[0][0]']
#                                 024)
#
#  sequential_94 (Sequential)     (None, 13, 14, 14,   12416       ['re_lu_122[0][0]']
#                                 32)
#
#  sequential_131 (Sequential)    (None, 2, 14, 14, 2  263168      ['re_lu_171[0][0]']
#                                 56)
#
#  sequential_95 (Sequential)     (None, 13, 14, 14,   9344        ['sequential_94[0][0]']
#                                 32)
#
#  sequential_132 (Sequential)    (None, 2, 14, 14, 2  590848      ['sequential_131[0][0]']
#                                 56)
#
#  conv3d_143 (Conv3D)            (None, 13, 14, 14,   4096        ['sequential_95[0][0]']
#                                 128)
#
#  conv3d_197 (Conv3D)            (None, 2, 14, 14, 1  262144      ['sequential_132[0][0]']
#                                 024)
#
#  batch_normalization_136 (Batch  (None, 13, 14, 14,   512        ['conv3d_143[0][0]']
#  Normalization)                 128)
#
#  batch_normalization_189 (Batch  (None, 2, 14, 14, 1  4096       ['conv3d_197[0][0]']
#  Normalization)                 024)
#
#  add_40 (Add)                   (None, 13, 14, 14,   0           ['batch_normalization_136[0][0]',
#                                 128)                              're_lu_122[0][0]']
#
#  add_56 (Add)                   (None, 2, 14, 14, 1  0           ['batch_normalization_189[0][0]',
#                                 024)                              're_lu_171[0][0]']
#
#  re_lu_125 (ReLU)               (None, 13, 14, 14,   0           ['add_40[0][0]']
#                                 128)
#
#  re_lu_174 (ReLU)               (None, 2, 14, 14, 1  0           ['add_56[0][0]']
#                                 024)
#
#  sequential_96 (Sequential)     (None, 13, 14, 14,   12416       ['re_lu_125[0][0]']
#                                 32)
#
#  sequential_133 (Sequential)    (None, 2, 14, 14, 2  263168      ['re_lu_174[0][0]']
#                                 56)
#
#  sequential_97 (Sequential)     (None, 13, 14, 14,   9344        ['sequential_96[0][0]']
#                                 32)
#
#  sequential_134 (Sequential)    (None, 2, 14, 14, 2  590848      ['sequential_133[0][0]']
#                                 56)
#
#  conv3d_146 (Conv3D)            (None, 13, 14, 14,   4096        ['sequential_97[0][0]']
#                                 128)
#
#  conv3d_200 (Conv3D)            (None, 2, 14, 14, 1  262144      ['sequential_134[0][0]']
#                                 024)
#
#  batch_normalization_139 (Batch  (None, 13, 14, 14,   512        ['conv3d_146[0][0]']
#  Normalization)                 128)
#
#  batch_normalization_192 (Batch  (None, 2, 14, 14, 1  4096       ['conv3d_200[0][0]']
#  Normalization)                 024)
#
#  add_41 (Add)                   (None, 13, 14, 14,   0           ['batch_normalization_139[0][0]',
#                                 128)                              're_lu_125[0][0]']
#
#  add_57 (Add)                   (None, 2, 14, 14, 1  0           ['batch_normalization_192[0][0]',
#                                 024)                              're_lu_174[0][0]']
#
#  re_lu_128 (ReLU)               (None, 13, 14, 14,   0           ['add_41[0][0]']
#                                 128)
#
#  re_lu_177 (ReLU)               (None, 2, 14, 14, 1  0           ['add_57[0][0]']
#                                 024)
#
#  sequential_98 (Sequential)     (None, 13, 14, 14,   12416       ['re_lu_128[0][0]']
#                                 32)
#
#  sequential_135 (Sequential)    (None, 2, 14, 14, 2  263168      ['re_lu_177[0][0]']
#                                 56)
#
#  sequential_99 (Sequential)     (None, 13, 14, 14,   9344        ['sequential_98[0][0]']
#                                 32)
#
#  sequential_136 (Sequential)    (None, 2, 14, 14, 2  590848      ['sequential_135[0][0]']
#                                 56)
#
#  conv3d_149 (Conv3D)            (None, 13, 14, 14,   4096        ['sequential_99[0][0]']
#                                 128)
#
#  conv3d_203 (Conv3D)            (None, 2, 14, 14, 1  262144      ['sequential_136[0][0]']
#                                 024)
#
#  batch_normalization_142 (Batch  (None, 13, 14, 14,   512        ['conv3d_149[0][0]']
#  Normalization)                 128)
#
#  batch_normalization_195 (Batch  (None, 2, 14, 14, 1  4096       ['conv3d_203[0][0]']
#  Normalization)                 024)
#
#  add_42 (Add)                   (None, 13, 14, 14,   0           ['batch_normalization_142[0][0]',
#                                 128)                              're_lu_128[0][0]']
#
#  add_58 (Add)                   (None, 2, 14, 14, 1  0           ['batch_normalization_195[0][0]',
#                                 024)                              're_lu_177[0][0]']
#
#  re_lu_131 (ReLU)               (None, 13, 14, 14,   0           ['add_42[0][0]']
#                                 128)
#
#  re_lu_180 (ReLU)               (None, 2, 14, 14, 1  0           ['add_58[0][0]']
#                                 024)
#
#  sequential_100 (Sequential)    (None, 13, 14, 14,   12416       ['re_lu_131[0][0]']
#                                 32)
#
#  sequential_137 (Sequential)    (None, 2, 14, 14, 2  263168      ['re_lu_180[0][0]']
#                                 56)
#
#  sequential_101 (Sequential)    (None, 13, 14, 14,   9344        ['sequential_100[0][0]']
#                                 32)
#
#  sequential_138 (Sequential)    (None, 2, 14, 14, 2  590848      ['sequential_137[0][0]']
#                                 56)
#
#  conv3d_152 (Conv3D)            (None, 13, 14, 14,   4096        ['sequential_101[0][0]']
#                                 128)
#
#  conv3d_206 (Conv3D)            (None, 2, 14, 14, 1  262144      ['sequential_138[0][0]']
#                                 024)
#
#  batch_normalization_145 (Batch  (None, 13, 14, 14,   512        ['conv3d_152[0][0]']
#  Normalization)                 128)
#
#  batch_normalization_198 (Batch  (None, 2, 14, 14, 1  4096       ['conv3d_206[0][0]']
#  Normalization)                 024)
#
#  add_43 (Add)                   (None, 13, 14, 14,   0           ['batch_normalization_145[0][0]',
#                                 128)                              're_lu_131[0][0]']
#
#  add_59 (Add)                   (None, 2, 14, 14, 1  0           ['batch_normalization_198[0][0]',
# ...
#
#  re_lu_137 (ReLU)               (None, 13, 14, 14,   0           ['add_44[0][0]']
#                                 128)
#
#  re_lu_186 (ReLU)               (None, 2, 14, 14, 1  0           ['add_60[0][0]']
#                                 024)
#
#  conv3d_156 (Conv3D)            (None, 2, 14, 14, 2  163840      ['re_lu_137[0][0]']
#                                 56)
#
#  concatenate_8 (Concatenate)    (None, 2, 14, 14, 1  0           ['re_lu_186[0][0]',
#                                 280)                              'conv3d_156[0][0]']
#
#  sequential_142 (Sequential)    (None, 2, 14, 14, 5  657408      ['concatenate_8[0][0]']
#                                 12)
#
#  sequential_105 (Sequential)    (None, 13, 14, 14,   24832       ['re_lu_137[0][0]']
#                                 64)
#
#  sequential_143 (Sequential)    (None, 2, 7, 7, 512  2361344     ['sequential_142[0][0]']
#                                 )
#
#  sequential_106 (Sequential)    (None, 13, 7, 7, 64  37120       ['sequential_105[0][0]']
#                                 )
#
#  conv3d_213 (Conv3D)            (None, 2, 7, 7, 204  1048576     ['sequential_143[0][0]']
#                                 8)
#
#  conv3d_160 (Conv3D)            (None, 13, 7, 7, 25  16384       ['sequential_106[0][0]']
#                                 6)
#
#  batch_normalization_205 (Batch  (None, 2, 7, 7, 204  8192       ['conv3d_213[0][0]']
#  Normalization)                 8)
#
#  sequential_141 (Sequential)    (None, 2, 7, 7, 204  2629632     ['concatenate_8[0][0]']
#                                 8)
#
#  batch_normalization_152 (Batch  (None, 13, 7, 7, 25  1024       ['conv3d_160[0][0]']
#  Normalization)                 6)
#
#  sequential_104 (Sequential)    (None, 13, 7, 7, 25  33792       ['re_lu_137[0][0]']
#                                 6)
#
#  add_61 (Add)                   (None, 2, 7, 7, 204  0           ['batch_normalization_205[0][0]',
#                                 8)                                'sequential_141[0][0]']
#
#  add_45 (Add)                   (None, 13, 7, 7, 25  0           ['batch_normalization_152[0][0]',
#                                 6)                                'sequential_104[0][0]']
#
#  re_lu_189 (ReLU)               (None, 2, 7, 7, 204  0           ['add_61[0][0]']
#                                 8)
#
#  re_lu_140 (ReLU)               (None, 13, 7, 7, 25  0           ['add_45[0][0]']
#                                 6)
#
#  sequential_144 (Sequential)    (None, 2, 7, 7, 512  1050624     ['re_lu_189[0][0]']
#                                 )
#
#  sequential_107 (Sequential)    (None, 13, 7, 7, 64  49408       ['re_lu_140[0][0]']
#                                 )
#
#  sequential_145 (Sequential)    (None, 2, 7, 7, 512  2361344     ['sequential_144[0][0]']
#                                 )
#
#  sequential_108 (Sequential)    (None, 13, 7, 7, 64  37120       ['sequential_107[0][0]']
#                                 )
#
#  conv3d_216 (Conv3D)            (None, 2, 7, 7, 204  1048576     ['sequential_145[0][0]']
#                                 8)
#
#  conv3d_163 (Conv3D)            (None, 13, 7, 7, 25  16384       ['sequential_108[0][0]']
#                                 6)
#
#  batch_normalization_208 (Batch  (None, 2, 7, 7, 204  8192       ['conv3d_216[0][0]']
#  Normalization)                 8)
#
#  batch_normalization_155 (Batch  (None, 13, 7, 7, 25  1024       ['conv3d_163[0][0]']
#  Normalization)                 6)
#
#  add_62 (Add)                   (None, 2, 7, 7, 204  0           ['batch_normalization_208[0][0]',
#                                 8)                                're_lu_189[0][0]']
#
#  add_46 (Add)                   (None, 13, 7, 7, 25  0           ['batch_normalization_155[0][0]',
#                                 6)                                're_lu_140[0][0]']
#
#  re_lu_192 (ReLU)               (None, 2, 7, 7, 204  0           ['add_62[0][0]']
#                                 8)
#
#  re_lu_143 (ReLU)               (None, 13, 7, 7, 25  0           ['add_46[0][0]']
#                                 6)
#
#  sequential_146 (Sequential)    (None, 2, 7, 7, 512  1050624     ['re_lu_192[0][0]']
#                                 )
#
#  sequential_109 (Sequential)    (None, 13, 7, 7, 64  49408       ['re_lu_143[0][0]']
#                                 )
#
#  sequential_147 (Sequential)    (None, 2, 7, 7, 512  2361344     ['sequential_146[0][0]']
#                                 )
#
#  sequential_110 (Sequential)    (None, 13, 7, 7, 64  37120       ['sequential_109[0][0]']
#                                 )
#
#  conv3d_219 (Conv3D)            (None, 2, 7, 7, 204  1048576     ['sequential_147[0][0]']
#                                 8)
#
#  conv3d_166 (Conv3D)            (None, 13, 7, 7, 25  16384       ['sequential_110[0][0]']
#                                 6)
#
#  batch_normalization_211 (Batch  (None, 2, 7, 7, 204  8192       ['conv3d_219[0][0]']
#  Normalization)                 8)
#
#  batch_normalization_158 (Batch  (None, 13, 7, 7, 25  1024       ['conv3d_166[0][0]']
#  Normalization)                 6)
#
#  add_63 (Add)                   (None, 2, 7, 7, 204  0           ['batch_normalization_211[0][0]',
#                                 8)                                're_lu_192[0][0]']
#
#  add_47 (Add)                   (None, 13, 7, 7, 25  0           ['batch_normalization_158[0][0]',
#                                 6)                                're_lu_143[0][0]']
#
#  re_lu_195 (ReLU)               (None, 2, 7, 7, 204  0           ['add_63[0][0]']
#                                 8)
#
#  re_lu_146 (ReLU)               (None, 13, 7, 7, 25  0           ['add_47[0][0]']
#                                 6)
#
#  global_average_pooling3d_3 (Gl  (None, 2048)        0           ['re_lu_195[0][0]']
#  obalAveragePooling3D)
#
#  global_average_pooling3d_2 (Gl  (None, 256)         0           ['re_lu_146[0][0]']
#  obalAveragePooling3D)
#
#  concatenate_9 (Concatenate)    (None, 2304)         0           ['global_average_pooling3d_3[0][0
#                                                                  ]',
#                                                                   'global_average_pooling3d_2[0][0
#                                                                  ]']
#
#  dropout_1 (Dropout)            (None, 2304)         0           ['concatenate_9[0][0]']
#
#  dense_1 (Dense)                (None, 14)           32270       ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 25,195,174
# Trainable params: 25,135,414
# Non-trainable params: 59,760
# __________________________________________________________________________________________________
# X_train.shape =  375
# X_val.shape =  67
# X_test.shape =  78
# Epoch 1/5
# 188/188 [==============================] - ETA: 0s - loss: 2.5219 - accuracy: 0.1547
# Epoch 1: saving model to output/slowfast-01-0.30.hdf5
# 188/188 [==============================] - 1454s 8s/step - loss: 2.5219 - accuracy: 0.1547 - val_loss: 2.4156 - val_accuracy: 0.2985
# Epoch 2/5
# 188/188 [==============================] - ETA: 0s - loss: 2.4484 - accuracy: 0.1707
# Epoch 2: saving model to output/slowfast-02-0.30.hdf5
# 188/188 [==============================] - 1185s 6s/step - loss: 2.4484 - accuracy: 0.1707 - val_loss: 2.3787 - val_accuracy: 0.2985
# Epoch 3/5
# 188/188 [==============================] - ETA: 0s - loss: 2.4380 - accuracy: 0.1733
# Epoch 3: saving model to output/slowfast-03-0.30.hdf5
# 188/188 [==============================] - 1625s 9s/step - loss: 2.4380 - accuracy: 0.1733 - val_loss: 2.3835 - val_accuracy: 0.2985
# Epoch 4/5
# 188/188 [==============================] - ETA: 0s - loss: 2.4327 - accuracy: 0.1733
# Epoch 4: saving model to output/slowfast-04-0.30.hdf5
# 188/188 [==============================] - 1716s 9s/step - loss: 2.4327 - accuracy: 0.1733 - val_loss: 2.3772 - val_accuracy: 0.2985
# Epoch 5/5
# 188/188 [==============================] - ETA: 0s - loss: 2.4270 - accuracy: 0.1600
# Epoch 5: saving model to output/slowfast-05-0.30.hdf5
# 188/188 [==============================] - 1649s 9s/step - loss: 2.4270 - accuracy: 0.1600 - val_loss: 2.3706 - val_accuracy: 0.2985
# 39/39 [==============================] - 79s 2s/step - loss: 2.3053 - accuracy: 0.2308
# Test loss: 2.3052940368652344
# Test accuracy: 0.23076923191547394

# %%
def frames_from_video(video_dir, nb_frames = 25, img_size = 224):

    # Opens the Video file
    cap = cv2.VideoCapture(video_dir)
    i=0
    frames = []
    while(cap.isOpened() and i<nb_frames):
        ret, frame = cap.read()
        if ret == False:
            break
        frame = cv2.resize(frame, (img_size, img_size))
        frames.append(frame)
        i+=1

    cap.release()
    cv2.destroyAllWindows()
    return np.array(frames) / 255.0
